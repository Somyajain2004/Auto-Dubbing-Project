# %%
# Install the stable version of PyTorch first
# !pip install torch==2.5.1 torchaudio --index-url https://download.pytorch.org/whl/cu118

# Install specific, compatible versions of transformers and TTS
# !pip install transformers==4.39.3
# !pip install TTS==0.22.0
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (2.5.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.5.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.8.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.8.86)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (3.0.2)
# Requirement already satisfied: transformers==4.39.3 in /usr/local/lib/python3.11/dist-packages (4.39.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (2.32.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.39.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.39.3) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.39.3) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.39.3) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.39.3) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.39.3) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.39.3) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.39.3) (2024.2.0)
# Requirement already satisfied: TTS==0.22.0 in /usr/local/lib/python3.11/dist-packages (0.22.0)
# Requirement already satisfied: cython>=0.29.30 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.0.12)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.15.3)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2.5.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2.5.1+cu118)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.13.1)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.7.2)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (7.5.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (4.67.1)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.3.3)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2025.5.1)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.12.13)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (25.0)
# Requirement already satisfied: flask>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.1.1)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.5.7)
# Requirement already satisfied: pandas<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.7.2)
# Requirement already satisfied: trainer>=0.0.32 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.17)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.42.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.55.0)
# Requirement already satisfied: hangul-romanize in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.2.3)
# Requirement already satisfied: jamo in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.9.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.2)
# Requirement already satisfied: bangla in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.5)
# Requirement already satisfied: bnnumerizer in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.8.1)
# Requirement already satisfied: transformers>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (4.39.3)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.4.0)
# Requirement already satisfied: num2words in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.5.14)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (3.8.7)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.26.4)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.60.0)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.17.0)
# Requirement already satisfied: dateparser~=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (0.9.11)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.20.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (3.1.3)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->TTS==0.22.0) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->TTS==0.22.0) (4.4.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (3.0.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (2.9.0.post0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words->TTS==0.22.0) (0.6.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57.0->TTS==0.22.0) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.3->TTS==0.22.0) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0,>=1.4->TTS==0.22.0) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.0->TTS==0.22.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->TTS==0.22.0) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.16.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.11.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (0.6.10)
# Requirement already satisfied: sudachidict_core>=20211220 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (20250825)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (3.18.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.8.86)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->TTS==0.22.0) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.32->TTS==0.22.0) (7.0.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.32->TTS==0.22.0) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.33.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.1->TTS==0.22.0) (0.5.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->TTS==0.22.0) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (5.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.33.0->TTS==0.22.0) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.0->TTS==0.22.0) (4.3.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2025.6.15)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (7.1.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.3->TTS==0.22.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.3->TTS==0.22.0) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.3->TTS==0.22.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.3->TTS==0.22.0) (2024.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.32->TTS==0.22.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.32->TTS==0.22.0) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.32->TTS==0.22.0) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.32->TTS==0.22.0) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.32->TTS==0.22.0) (0.7.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.3->TTS==0.22.0) (2024.2.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.1.2)

# %%
from TTS.api import TTS

# %%
import json

with open("/kaggle/input/eng-to-hindi-text-art38/Article_38_text_translated_hi.json", encoding="utf-8") as f:
    segments = json.load(f)

print(f"Loaded {len(segments)} transcribed segments")
# Out:
# Loaded 20 transcribed segments

# %% [markdown]
# # **Creating audio references**

# %%
from pydub import AudioSegment
import os

# --- This is the new code to automatically create reference clips ---

# Make sure you have the path to your original multi-speaker WAV file in your Kaggle input
audio_file = "/kaggle/input/ip-audio/Article_38.wav" 

# And you have the 'segments' list from the diarization step

print("Creating speaker reference clips...")

# 1. Load the main audio file (using .from_wav for a WAV file)
full_audio = AudioSegment.from_wav(audio_file)

# 2. Create a directory in Kaggle's writable output folder
ref_clips_dir = "/kaggle/working/speaker_references/"
os.makedirs(ref_clips_dir, exist_ok=True)

# 3. Find unique speakers
unique_speakers = set(seg['speaker'] for seg in segments)

# This dictionary will hold the path to the reference clip for each speaker
speaker_references = {}

# 4. Extract the longest segment for each speaker
for speaker_id in unique_speakers:
    # Find all segments for the current speaker
    speaker_segments = [s for s in segments if s['speaker'] == speaker_id]
    
    # Find the longest segment among them
    longest_seg = max(speaker_segments, key=lambda s: s['end'] - s['start'])
    
    # Get start and end times in milliseconds
    start_ms = int(longest_seg['start'] * 1000)
    end_ms = int(longest_seg['end'] * 1000)
    
    # Slice the audio to get the reference clip
    reference_clip = full_audio[start_ms:end_ms]
    
    # Define the output path for the clip
    clip_path = os.path.join(ref_clips_dir, f"reference_{speaker_id}.wav")
    
    # Export the clip as a WAV file
    reference_clip.export(clip_path, format="wav")
    
    # Store the path in our dictionary
    speaker_references[speaker_id] = clip_path
    
    print(f"  > Saved reference clip for {speaker_id} at {clip_path}")

print("\nFinished creating reference clips. The 'speaker_references' dictionary is now ready:")
print(speaker_references)

# --- Now you can proceed with the TTS synthesis using this dictionary ---
# Out:
# Creating speaker reference clips...
#   > Saved reference clip for SPEAKER_00 at /kaggle/working/speaker_references/reference_SPEAKER_00.wav
#   > Saved reference clip for SPEAKER_01 at /kaggle/working/speaker_references/reference_SPEAKER_01.wav
#
# Finished creating reference clips. The 'speaker_references' dictionary is now ready:
# {'SPEAKER_00': '/kaggle/working/speaker_references/reference_SPEAKER_00.wav', 'SPEAKER_01': '/kaggle/working/speaker_references/reference_SPEAKER_01.wav'}

# %% [markdown]
# # **Voice Cloning**

# %%
import torch
from TTS.api import TTS
from TTS.tts.configs.xtts_config import XttsConfig
import os

speaker_references = {
    "SPEAKER_00": "/kaggle/working/speaker_references/reference_SPEAKER_00.wav",
    "SPEAKER_01": "/kaggle/working/speaker_references/reference_SPEAKER_01.wav",
}

# --- NEW, MORE ROBUST FIX ---
# This command tells PyTorch to trust this class for the entire session.
torch.serialization.add_safe_globals([XttsConfig])


device = "cuda" if torch.cuda.is_available() else "cpu"

# Now, load the model normally (without the 'with' block)
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)


# --- The rest of your code continues as normal ---

# Output directory
output_dir = "/kaggle/working/dubbed_clips/"
os.makedirs(output_dir, exist_ok=True)

# Generate dubbed audio
print("Starting audio synthesis for all segments...")
for i, seg in enumerate(segments):
    output_path = os.path.join(output_dir, f"segment_{i}_{seg['speaker']}.wav")

    print(f"  > Generating clip for {seg['speaker']} saying: \"{seg['translated_text'][:30]}...\"")

    tts.tts_to_file(
        text=seg['translated_text'],
        speaker_wav=speaker_references[seg['speaker']],
        language="hi",
        file_path=output_path
    )
    seg['dubbed_audio_path'] = output_path
    
print("\n All dubbed clips have been generated successfully!")
print("They are saved in:", output_dir)

# %%
from TTS.api import TTS
import torch
import os
# from TTS.tts.configs.xtts_config import XttsConfig

device = "cuda" if torch.cuda.is_available() else "cpu"


tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

# Reference audio
speaker_references = {
    "SPEAKER_00": "/kaggle/working/speaker_references/reference_SPEAKER_00.wav",
    "SPEAKER_01": "/kaggle/working/speaker_references/reference_SPEAKER_01.wav",
}


# Output directory
output_dir = "/kaggle/working/dubbed_clips/"
os.makedirs(output_dir, exist_ok=True)

# Generate dubbed audio
print("Starting audio synthesis for all segments...")
for i, seg in enumerate(segments):
    output_path = os.path.join(output_dir, f"segment_{i}_{seg['speaker']}.wav")

    tts.tts_to_file(
        text=seg['translated_text'],
        speaker_wav=speaker_references[seg['speaker']],
        language="hi",
        file_path=output_path
    )
    seg['dubbed_audio_path'] = output_path
    print(f"Generated dubbed clip: {output_path}")

print("All dubbed clips are saved in:", output_dir)
# Out:
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | >  y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.86G/1.87G [00:18<00:00, 86.5MiB/s]
# 100%|██████████| 1.87G/1.87G [00:18<00:00, 101MiB/s]
# 4.37kiB [00:00, 18.4kiB/s]
#
# 361kiB [00:00, 1.30MiB/s]0 [00:00<?, ?iB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 88.2iB/s]
#  62%|██████▏   | 4.82M/7.75M [00:00<00:00, 48.2MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
#  > Using model: xtts
# 100%|██████████| 7.75M/7.75M [00:10<00:00, 48.2MiB/s]/usr/local/lib/python3.11/dist-packages/TTS/tts/layers/xtts/xtts_manager.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.speakers = torch.load(speaker_file_path)
# /usr/local/lib/python3.11/dist-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
# Starting audio synthesis for all segments...
#  > Text splitted to sentences.
# ['यह उचित नहीं है कि आप बाजार कम कीमतों के साथ बाढ़ कर सकते हैं, क्योंकि आपके पास अधिक साधन हैं.']
#  > Processing time: 5.702317953109741
#  > Real-time factor: 0.5881675719728585
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_0_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['मैं सिर्फ अपने व्यापार के लिए सबसे अच्छा क्या कर रहा हूँ.']
#  > Processing time: 3.2470827102661133
#  > Real-time factor: 0.44039817538485265
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_1_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['अगर मैं कम कीमत दे सकते हैं, कि सिर्फ प्रतियोगिता है.', 'यह आप के लिए ऊपर रखने या कदम रखने के लिए ऊपर या कदम रखने के लिए है.']
#  > Processing time: 6.493540525436401
#  > Real-time factor: 0.4420961632554609
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_2_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['लेकिन यह सिर्फ एक बुरी प्रतियोगिता नहीं है.']
#  > Processing time: 2.7241051197052
#  > Real-time factor: 0.4312644880061722
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_3_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['ऐसा लगता है कि आप हमें धक्का देने के लिए अपने लाभ का उपयोग कर रहे हैं, और यह सही नहीं है.']
#  > Processing time: 3.4391517639160156
#  > Real-time factor: 0.4362246686283257
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_4_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['मैं बाजार में पक्षपात के बारे में यहाँ एक विवाद है.']
#  > Processing time: 2.8254592418670654
#  > Real-time factor: 0.4368715379443565
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_5_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['हाय, मैं राजा हूँ, एक सरकारी अधिकारी.']
#  > Processing time: 2.319398880004883
#  > Real-time factor: 0.42956881890965315
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_6_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['चलो इस अच्छी तरह से पता करते हैं.']
#  > Processing time: 4.070814371109009
#  > Real-time factor: 0.44268058511675235
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_7_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['क्या समस्या है लगता है.']
#  > Processing time: 5.34286093711853
#  > Real-time factor: 0.43700695762160807
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_8_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['यह बड़ी दुकान के पास अधिक संसाधन है, और वह उपयोग कर रहा है कि कीमत काटने के लिए और मेरे जैसे छोटे विक्रेताओं को बाहर निकालना। यह वास्तव में हमारे लिए संघर्ष करने के लिए मुश्किल बना रहा है।']
#  > Processing time: 8.397124290466309
#  > Real-time factor: 0.43859340203899494
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_9_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['मैं सिर्फ ग्राहकों को आकर्षित करने के लिए बेहतर कीमत पेश करने की कोशिश कर रहा हूँ। यह मेरी गलती नहीं है कि छोटे विक्रेता इसे मैच नहीं कर सकते। हमारे संविधान 38 में, राज्य न्याय और समानता को बढ़ावा देने के लिए प्रयास करता है।']
#  > Processing time: 6.252752065658569
#  > Real-time factor: 0.4403430906273042
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_10_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['इसका मतलब है कि हर किसी के पास उचित मौका है। चलो इस स्थिति को संतुलित करने के लिए कुछ तरीके पर चर्चा करें। आम तौर पर, जबकि प्रतियोगिता स्वस्थ है, और यह उचित है। कैसे छोटे विक्रेताओं के साथ साझा करने के बारे में है छोटे उत्पादों की तरह। इस तरह, आप अपने आधार को पूरी तरह से चला सकते हैं बाहर चला जा सकता है।']
# [!] Warning: The text length exceeds the character limit of 250 for language 'hi', this might cause truncated audio.
#  > Processing time: 12.194329023361206
#  > Real-time factor: 0.45019447843016586
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_11_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['मैं अपने दुकान के कुछ उत्पादों की विशेषता कर सकता है और उसकी पहुँच अधिक ग्राहकों की मदद कर सकता है। यह हम दोनों को लाभ हो सकता है। एनता, कैसे एक छोटी कंपनी स्थापित करने के बारे में, जहां आप और अन्य लोग एक साथ काम कर सकते हैं और एक दूसरे की मदद करने के लिए काम कर सकते हैं?', 'राज्य भी संसाधनों और आप अपने व्यापार योजनाओं को बेहतर बनाने में मदद कर सकते हैं।']
# [!] Warning: The text length exceeds the character limit of 250 for language 'hi', this might cause truncated audio.
#  > Processing time: 14.305919647216797
#  > Real-time factor: 0.44385937038634443
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_12_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['हाँ.']
#  > Processing time: 4.600220680236816
#  > Real-time factor: 0.4377929096713875
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_13_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['ऐसे ही हालात में दूसरों के साथ मिलकर काम करना और उनके साथ काम करना बहुत बड़ी बात होगी ।']
#  > Processing time: 3.566124200820923
#  > Real-time factor: 0.43319214757658303
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_14_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['मुझे खुशी है कि हम इस चर्चा थी.']
#  > Processing time: 2.4694316387176514
#  > Real-time factor: 0.448673101794036
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_15_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['चलो इन विचारों पर काम करते हैं और देखते हैं कि कैसे हम बाजार को सब के लिए बेहतर बना सकते हैं।']
#  > Processing time: 3.586513042449951
#  > Real-time factor: 0.4438056286815425
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_16_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['हाँ, मैं भी खुश हूँ.']
#  > Processing time: 2.697866916656494
#  > Real-time factor: 0.4271106082156497
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_17_SPEAKER_01.wav
#  > Text splitted to sentences.
# ['इस बाहर स्पष्ट करने के लिए धन्यवाद.']
#  > Processing time: 2.502617120742798
#  > Real-time factor: 0.43453688037339905
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_18_SPEAKER_00.wav
#  > Text splitted to sentences.
# ['यही कारण है कि आलेख 38 की आत्मा है, हमारे जीवन के सभी पहलुओं में न्याय और समानता को स्थापित करने के लिए एक साथ काम करते हैं.', 'सहयोग देने और एक दूसरे का समर्थन करने के द्वारा, हम एक बाजार बना सकते हैं कि हर किसी को लाभ.']
#  > Processing time: 8.611675500869751
#  > Real-time factor: 0.43809395716633903
# Generated dubbed clip: /kaggle/working/dubbed_clips/segment_19_SPEAKER_00.wav
# All dubbed clips are saved in: /kaggle/working/dubbed_clips/

# %%
segments
# Out:
# [{'start': 2.2078437500000003,
#   'end': 12.653468750000002,
#   'speaker': 'SPEAKER_01',
#   'text': " Ahmeed, your prices are driving all the small vendors like me out of business. It's not fair that you can just flood the market with lower prices, because you have more resources.",
#   'translated_text': 'यह उचित नहीं है कि आप बाजार कम कीमतों के साथ बाढ़ कर सकते हैं, क्योंकि आपके पास अधिक साधन हैं.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_0_SPEAKER_01.wav'},
#  {'start': 13.125968750000002,
#   'end': 15.437843750000004,
#   'speaker': 'SPEAKER_00',
#   'text': " I'm just doing what's best for my business.",
#   'translated_text': 'मैं सिर्फ अपने व्यापार के लिए सबसे अच्छा क्या कर रहा हूँ.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_1_SPEAKER_00.wav'},
#  {'start': 15.67409375,
#   'end': 21.51284375,
#   'speaker': 'SPEAKER_00',
#   'text': " If I can offer lower prices, that's just competition. It's up to you to keep up or step aside.",
#   'translated_text': 'अगर मैं कम कीमत दे सकते हैं, कि सिर्फ प्रतियोगिता है. यह आप के लिए ऊपर रखने या कदम रखने के लिए ऊपर या कदम रखने के लिए है.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_2_SPEAKER_00.wav'},
#  {'start': 22.08659375,
#   'end': 24.11159375,
#   'speaker': 'SPEAKER_01',
#   'text': " But it's not just a bad competition.",
#   'translated_text': 'लेकिन यह सिर्फ एक बुरी प्रतियोगिता नहीं है.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_3_SPEAKER_01.wav'},
#  {'start': 24.49971875,
#   'end': 28.78596875,
#   'speaker': 'SPEAKER_01',
#   'text': " It feels like you're using your advantage to push us out, and that's not right.",
#   'translated_text': 'ऐसा लगता है कि आप हमें धक्का देने के लिए अपने लाभ का उपयोग कर रहे हैं, और यह सही नहीं है.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_4_SPEAKER_01.wav'},
#  {'start': 31.23284375,
#   'end': 34.540343750000005,
#   'speaker': 'SPEAKER_00',
#   'text': " I see there's a dispute here regarding fairness in the marketplace.",
#   'translated_text': 'मैं बाजार में पक्षपात के बारे में यहाँ एक विवाद है.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_5_SPEAKER_00.wav'},
#  {'start': 34.92846875,
#   'end': 37.54409375,
#   'speaker': 'SPEAKER_00',
#   'text': " Hi, I'm Raj, a government official.",
#   'translated_text': 'हाय, मैं राजा हूँ, एक सरकारी अधिकारी.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_6_SPEAKER_00.wav'},
#  {'start': 37.72971875,
#   'end': 39.68721875,
#   'speaker': 'SPEAKER_00',
#   'text': " Let's address this constructively.",
#   'translated_text': 'चलो इस अच्छी तरह से पता करते हैं.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_7_SPEAKER_00.wav'},
#  {'start': 39.97409375,
#   'end': 41.47596875,
#   'speaker': 'SPEAKER_00',
#   'text': ' what seems to be the problem.',
#   'translated_text': 'क्या समस्या है लगता है.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_8_SPEAKER_00.wav'},
#  {'start': 41.89784375,
#   'end': 51.938468750000006,
#   'speaker': 'SPEAKER_01',
#   'text': " Amit's larger shop has more resources, and he's using that to undercut prices and squeeze out smaller vendors like me. It's making it really hard for us to compete.",
#   'translated_text': 'यह बड़ी दुकान के पास अधिक संसाधन है, और वह उपयोग कर रहा है कि कीमत काटने के लिए और मेरे जैसे छोटे विक्रेताओं को बाहर निकालना। यह वास्तव में हमारे लिए संघर्ष करने के लिए मुश्किल बना रहा है।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_9_SPEAKER_01.wav'},
#  {'start': 52.37721875,
#   'end': 64.64534375000001,
#   'speaker': 'SPEAKER_00',
#   'text': " I'm just trying to offer better prices to attract customers. It's not my fault that smaller vendors can't match it. Under Article 38 of our Constitution, the state strives to promote justice and equality.",
#   'translated_text': 'मैं सिर्फ ग्राहकों को आकर्षित करने के लिए बेहतर कीमत पेश करने की कोशिश कर रहा हूँ। यह मेरी गलती नहीं है कि छोटे विक्रेता इसे मैच नहीं कर सकते। हमारे संविधान 38 में, राज्य न्याय और समानता को बढ़ावा देने के लिए प्रयास करता है।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_10_SPEAKER_00.wav'},
#  {'start': 64.72971875,
#   'end': 86.46471875,
#   'speaker': 'SPEAKER_00',
#   'text': " This means we need to ensure that everyone has a fair chance. Let's discuss some ways to balance this situation. Amit, while competition is healthy, there are ways to ensure it's fair. How about collaborating with smaller vendors like Nita to offer a variety of products at different price points? This way, you can maintain your customer base without completely driving others out.",
#   'translated_text': 'इसका मतलब है कि हर किसी के पास उचित मौका है। चलो इस स्थिति को संतुलित करने के लिए कुछ तरीके पर चर्चा करें। आम तौर पर, जबकि प्रतियोगिता स्वस्थ है, और यह उचित है। कैसे छोटे विक्रेताओं के साथ साझा करने के बारे में है छोटे उत्पादों की तरह। इस तरह, आप अपने आधार को पूरी तरह से चला सकते हैं बाहर चला जा सकता है।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_11_SPEAKER_00.wav'},
#  {'start': 87.05534375,
#   'end': 106.41096875,
#   'speaker': 'SPEAKER_00',
#   'text': " I could feature some of Nita's products in my shop and help her reach more customers. It could benefit both of us. Nita, how about setting up a small vendor association where you and others can work together to offer unique products and support each other? The state can also assist with resources and training to help you improve your business strategies.",
#   'translated_text': 'मैं अपने दुकान के कुछ उत्पादों की विशेषता कर सकता है और उसकी पहुँच अधिक ग्राहकों की मदद कर सकता है। यह हम दोनों को लाभ हो सकता है। एनता, कैसे एक छोटी कंपनी स्थापित करने के बारे में, जहां आप और अन्य लोग एक साथ काम कर सकते हैं और एक दूसरे की मदद करने के लिए काम कर सकते हैं? राज्य भी संसाधनों और आप अपने व्यापार योजनाओं को बेहतर बनाने में मदद कर सकते हैं।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_12_SPEAKER_00.wav'},
#  {'start': 106.90034375,
#   'end': 107.47409375,
#   'speaker': 'SPEAKER_01',
#   'text': ' Yes.',
#   'translated_text': 'हाँ.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_13_SPEAKER_01.wav'},
#  {'start': 107.86221875,
#   'end': 112.89096875,
#   'speaker': 'SPEAKER_01',
#   'text': ' It would be great to have some support and work together with others in similar situations.',
#   'translated_text': 'ऐसे ही हालात में दूसरों के साथ मिलकर काम करना और उनके साथ काम करना बहुत बड़ी बात होगी ।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_14_SPEAKER_01.wav'},
#  {'start': 113.86971875,
#   'end': 115.64159375,
#   'speaker': 'SPEAKER_00',
#   'text': " I'm glad we had this discussion.",
#   'translated_text': 'मुझे खुशी है कि हम इस चर्चा थी.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_15_SPEAKER_00.wav'},
#  {'start': 116.02971875,
#   'end': 120.24846875,
#   'speaker': 'SPEAKER_00',
#   'text': " Let's work on these ideas and see how we can make the market fairer for everyone.",
#   'translated_text': 'चलो इन विचारों पर काम करते हैं और देखते हैं कि कैसे हम बाजार को सब के लिए बेहतर बना सकते हैं।',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_16_SPEAKER_00.wav'},
#  {'start': 121.21034375,
#   'end': 122.84721875,
#   'speaker': 'SPEAKER_01',
#   'text': " Yes, I'm glad too.",
#   'translated_text': 'हाँ, मैं भी खुश हूँ.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_17_SPEAKER_01.wav'},
#  {'start': 123.33659375,
#   'end': 125.17596875,
#   'speaker': 'SPEAKER_00',
#   'text': ' Thank you for clearing this out.',
#   'translated_text': 'इस बाहर स्पष्ट करने के लिए धन्यवाद.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_18_SPEAKER_00.wav'},
#  {'start': 125.22659375,
#   'end': 137.10659375,
#   'speaker': 'SPEAKER_00',
#   'text': " That's the spirit of Article 38, working together to ensure justice and equality in all aspects of our lives. By collaborating and supporting each other, we can create a marketplace that benefits everyone.",
#   'translated_text': 'यही कारण है कि आलेख 38 की आत्मा है, हमारे जीवन के सभी पहलुओं में न्याय और समानता को स्थापित करने के लिए एक साथ काम करते हैं. सहयोग देने और एक दूसरे का समर्थन करने के द्वारा, हम एक बाजार बना सकते हैं कि हर किसी को लाभ.',
#   'dubbed_audio_path': '/kaggle/working/dubbed_clips/segment_19_SPEAKER_00.wav'}]

# %%
from pydub import AudioSegment
import os

# Your 'segments' list from the diarization/transcription/translation steps
# segments = [...]

# 1. Create an empty AudioSegment to build upon
final_audio = AudioSegment.empty()

# 2. Define the directory where your clips are stored
clips_dir = "/kaggle/working/dubbed_clips/"

print("Assembling the final audio by concatenating clips sequentially...")

# 3. Loop through the segments in order and append each clip
for i, seg in enumerate(segments):
    # Construct the path to the current dubbed clip
    speaker_id = seg['speaker']
    clip_path = os.path.join(clips_dir, f"segment_{i}_{speaker_id}.wav")
    
    # Load the clip
    current_clip = AudioSegment.from_wav(clip_path)
    
    # Append the clip to the end of our final audio
    final_audio += current_clip

# 4. Export the final result
# We'll use a new name to avoid overwriting the previous version
final_output_path = "/kaggle/working/final_dubbed_concatenated.mp3"
final_audio.export(final_output_path, format="mp3")

print(f"\n Success! Sequentially concatenated audio saved to: {final_output_path}")
# Out:
# Assembling the final audio by concatenating clips sequentially...
#
# 🎉 Success! Sequentially concatenated audio saved to: /kaggle/working/final_dubbed_concatenated.mp3
